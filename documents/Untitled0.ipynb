# %%
# %cd /content/drive/MyDrive/NienLuanChuyenNganh
# Out:
# /content/drive/MyDrive/NienLuanChuyenNganh

# %% [markdown]
# # New Section

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14166, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 14166 (delta 64), reused 83 (delta 50), pack-reused 14060
# Receiving objects: 100% (14166/14166), 13.60 MiB | 8.72 MiB/s, done.
# Resolving deltas: 100% (9727/9727), done.
# /content/drive/MyDrive/NienLuanChuyenNganh/yolov5
#      |████████████████████████████████| 182 kB 30.0 MB/s
#      |████████████████████████████████| 62 kB 1.3 MB/s
#      |████████████████████████████████| 1.6 MB 57.0 MB/s
#      |████████████████████████████████| 41 kB 515 kB/s
#      |████████████████████████████████| 145 kB 69.2 MB/s
#      |████████████████████████████████| 54 kB 3.1 MB/s
#      |████████████████████████████████| 138 kB 71.8 MB/s
#      |████████████████████████████████| 67 kB 3.0 MB/s
#      |████████████████████████████████| 178 kB 70.7 MB/s
#      |████████████████████████████████| 62 kB 1.0 MB/s
# ...

# %%
# !unzip /content/drive/MyDrive/NienLuanChuyenNganh/datanumplate.zip -d /content/drive/MyDrive/NienLuanChuyenNganh/yolov5
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/NienLuanChuyenNganh/yolov5/datanumplate/images/train/4xemay2100.jpg
#   inflating: /content/drive/MyDrive/NienLuanChuyenNganh/yolov5/datanumplate/images/train/4xemay2101.jpg
#   inflating: /content/drive/MyDrive/NienLuanChuyenNganh/yolov5/datanumplate/images/train/4xemay2102.jpg
#   inflating: /content/drive/MyDrive/NienLuanChuyenNganh/yolov5/datanumplate/images/train/4xemay2105.jpg
#   inflating: /content/drive/MyDrive/NienLuanChuyenNganh/yolov5/datanumplate/images/train/4xemay2107.jpg
#   inflating: /content/drive/MyDrive/NienLuanChuyenNganh/yolov5/datanumplate/images/train/4xemay2111.jpg
#   inflating: /content/drive/MyDrive/NienLuanChuyenNganh/yolov5/datanumplate/images/train/4xemay2113.jpg
#   inflating: /content/drive/MyDrive/NienLuanChuyenNganh/yolov5/datanumplate/images/train/4xemay2115.jpg
# ...

# %%
# %cd /content/drive/MyDrive/NienLuanChuyenNganh/yolov5
# !python train.py --img 416 --batch 64 --epochs 500 --data datanumplate/datanumplate.yaml --weights yolov5s.pt --cache
# Out:
# /content/drive/MyDrive/NienLuanChuyenNganh/yolov5
# train: weights=yolov5s.pt, cfg=, data=datanumplate/datanumplate.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-8-g350e8eb Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# %cd /content/drive/MyDrive/NienLuanChuyenNganh/yolov5
# !python detect.py --weights runs/train/exp2/weights/best.pt --imgsz 416 416 --source /content/bien-so-xe-1.png
# Out:
# /content/drive/MyDrive/NienLuanChuyenNganh/yolov5
# detect: weights=['runs/train/exp2/weights/best.pt'], source=/content/bien-so-xe-1.png, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-8-g350e8eb Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7091035 parameters, 0 gradients
# image 1/1 /content/bien-so-xe-1.png: 288x416 2 1s, 3 5s, 1 6, 1 7, 1 8, 12.2ms
# Speed: 0.3ms pre-process, 12.2ms inference, 1.5ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp9

# %%
# %cd /content/drive/MyDrive/NienLuanChuyenNganh/yolov5
# !python export.py --data datanumplate/datanumplate.yaml --weights runs/train/exp2/weights/best.pt --imgsz 416 416 --include tflite
# Out:
# /content/drive/MyDrive/NienLuanChuyenNganh/yolov5
# export: data=datanumplate/datanumplate.yaml, weights=['runs/train/exp2/weights/best.pt'], imgsz=[416, 416], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-8-g350e8eb Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7091035 parameters, 0 gradients
#
# PyTorch: starting from runs/train/exp2/weights/best.pt with output shape (1, 10647, 35) (13.8 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.9.2...
#
#                  from  n    params  module                                  arguments
# ...

# %%
# %cd /content/drive/MyDrive/NienLuanChuyenNganh/yolov5
# !python export.py --data datanumplate/datanumplate.yaml --weights runs/train/exp2/weights/best.pt --imgsz 416 416 --include onnx
